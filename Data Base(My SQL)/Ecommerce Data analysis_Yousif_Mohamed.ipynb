# %% [markdown]
# # <center> E-commerce data analysis </center>

# %% [markdown]
# ![w3schools_schema.png](attachment:w3schools_schema.png)

# %% [markdown]
# ## Fist, we need to connect to database

# %%
# using mysql.connector 
import mysql.connector
import pandas as pd

# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')

# %% [markdown]
# ## How we work with mysql.connector

# %% [markdown]
# ### 1. Define a cursor

# %%
cursor=conn.cursor()

# %% [markdown]
# ### 2. Write SQL query ... Then execute it.

# %%
# Write SQL query 
cursor.execute("select * from customers")

# %%
result=cursor.fetchone()

# %%
# Then execute it. ! 
result
# Out:
# (1,
#  'Alfreds Futterkiste',
#  'Maria Anders',
#  'Obere Str. 57',
#  'Berlin',
#  '12209',
#  'Germany')

# %%
cursor.description
# Out:
# [('CustomerID', 3, None, None, None, None, 0, 49667, 63),
#  ('CustomerName', 253, None, None, None, None, 1, 0, 255),
#  ('ContactName', 253, None, None, None, None, 1, 0, 255),
#  ('Address', 253, None, None, None, None, 1, 0, 255),
#  ('City', 253, None, None, None, None, 1, 0, 255),
#  ('PostalCode', 253, None, None, None, None, 1, 0, 255),
#  ('Country', 253, None, None, None, None, 1, 0, 255)]

# %% [markdown]
# ### 3. Show data

# %%
# Data columns
cursor.column_names
# Out:
# ('CustomerID',
#  'CustomerName',
#  'ContactName',
#  'Address',
#  'City',
#  'PostalCode',
#  'Country')

# %%
# Data items 
cursor.execute("select * from customers")
result=cursor.fetchall()
for r in result:
    print(r)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')
# (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain')
# (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France')
# ...

# %% [markdown]
# > Note: You cannot read the same query twice without return cursor to start point

# %% [markdown]
# ## 4. Save data as a table using pandas

# %%
df=pd.read_sql("select * from customers",con=conn)

# %%
df
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
df.to_csv("customers.csv")

# %% [markdown]
# #### 5. Close connection

# %%
conn.close()

# %% [markdown]
# # <center> Let's dive into analysis and find question answer ! </center>

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()

# %% [markdown]
# #####  What is countries we are working with ?

# %%
# Answer here

query="select country from customers"

cursor.execute(query)
result=cursor.fetchall()
for r in result:
    print(r)

# %% [markdown]
# #####  What is the number of countries we are working with ?

# %%
cursor.execute("select count(distintc country) from customers")

# %% [markdown]
# ##### How many mexico customers ?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("SELECT COUNT(customerid) FROM customers WHERE country='mexico'")

# %% [markdown]
# ##### How many customers in Germany and Spain?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(customerid) from customers where country in ('Germany','Spain')")

# %% [markdown]
# #####  How many customers in Germany and Spain?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(customerid) from customers where country in ('Germany','Spain')")

# %% [markdown]
# ##### show products withh ordering by it's price

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(customerid) from customers where country in ('Germany','Spain')")

# %% [markdown]
# ##### What is the smallest product price ?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select min(price) from products")

# %% [markdown]
# ##### What is the most expensive product  ?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select max(price) from products")

# %% [markdown]
# ##### How many product we have?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(productname) from products")

# %% [markdown]
# #####  What is the average product price?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select avg(price) from products")

# %% [markdown]
# #####  What is the total product price?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select sum(price) from products")

# %% [markdown]
# ##### How many products we store it in jars ?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(productname) from products where unit='%jars'")

# %% [markdown]
# ##### How many customers in Germany, France and UK?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select count(customername) from customers where country in ('Germany', 'France' , 'UK')")

# %% [markdown]
# ##### Show orders which ordered in JULY?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("select Quantity from order_details od inner join orders o on od.orderid=o.orderid where month(6)")

# %% [markdown]
# ##### Show the order ID with customer name ?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("""
select *
from customers c left join orders o
on c.customerid=o.customerid
union
select *
from customers c right join orders o
on c.customerid=o.customerid
""")

# %% [markdown]
# ##### Show all customers, and any orders they might have?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("""
select *
from customers c left join orders o
on c.customerid=o.customerid
""")

# %% [markdown]
# ##### What is the number of customers in each country?

# %%
# Answer here
import mysql.connector

# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("""
select country,count(customerid) as customers
from customers
group by country;
""")

# %% [markdown]
# ##### What is the number of customers in each country (show only above 5 customers)?

# %%
# Should fill the information about database we working with. 
conn=mysql.connector.connect(user='root',password='ym108754',host='127.0.0.1',database='w3schools')
# Define cursor
cursor=conn.cursor()
cursor.execute("""
select country,count(customerid) as customers
from customers
group by country
limit 5
""")

# %% [markdown]
# # Thanks
